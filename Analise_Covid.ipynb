# %%
import pandas as pd

dados_covid = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dados covid/HIST_PAINEL_COVIDBR_2024_Parte1_27fev2024.csv', sep=';')

dados_covid
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 309040  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 309041  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 309042  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 309043  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 309044  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
# Novos casos da variante

dados_covid[dados_covid.estado.isna()].casosNovos.plot()
# Out:
# <Axes: >

# %%
# Casos acumulados da variante

dados_covid[dados_covid.estado.isna()].casosAcumulado.plot()
# Out:
# <Axes: >

# %%
# Novos obitos

dados_covid[dados_covid.estado.isna()].obitosNovos.plot()
# Out:
# <Axes: >

# %%
# Obitos acumulados

dados_covid[dados_covid.estado.isna()].obitosAcumulado.plot()
# Out:
# <Axes: >

# %%
#Análise estatística

dados_covid.describe(include='all')
# Out:
#           regiao  estado  municipio          coduf         codmun  \
# count     309045  308990     306350  309045.000000  307505.000000
# unique         6      27       5297            NaN            NaN
# top     Nordeste      MG  Bom Jesus            NaN            NaN
# freq       99660   47025        275            NaN            NaN
# mean         NaN     NaN        NaN      32.360384  325258.014130
# std          NaN     NaN        NaN       9.873312   98535.184417
# min          NaN     NaN        NaN      11.000000  110000.000000
# 25%          NaN     NaN        NaN      25.000000  251200.000000
# 50%          NaN     NaN        NaN      31.000000  314610.000000
# 75%          NaN     NaN        NaN      41.000000  411915.000000
# max          NaN     NaN        NaN      76.000000  530010.000000
#
#         codRegiaoSaude nomeRegiaoSaude        data      semanaEpi  \
# count    306350.000000          306350      309045  309045.000000
# ...

# %%
#Correlação
dados_covid.corr()
# Out:
# <ipython-input-7-e576f2e2edf9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados_covid.corr()
#                                coduf        codmun  codRegiaoSaude  \
# coduf                   1.000000e+00  9.998693e-01    9.999930e-01
# codmun                  9.998693e-01  1.000000e+00    9.998902e-01
# codRegiaoSaude          9.999930e-01  9.998902e-01    1.000000e+00
# semanaEpi              -2.089985e-15 -2.226856e-15   -2.316496e-15
# populacaoTCU2019        5.618575e-02 -2.372734e-03   -2.572671e-03
# casosAcumulado          6.161650e-02  3.784790e-02    3.790632e-02
# casosNovos              1.970007e-02  1.517187e-03    1.535624e-03
# obitosAcumulado         5.907192e-02  1.744466e-02    1.714293e-02
# obitosNovos             1.011883e-02  3.589183e-04    3.524216e-04
# ...

# %%
# Identificação de outliers

dados_covid.sort_values(by=['obitosNovos']).head()
# Out:
#           regiao estado                municipio  coduf    codmun  \
# 398712  Nordeste     BA                 Salvador     29  292740.0
# 398896  Nordeste     BA            Santa Bárbara     29  292750.0
# 274972  Nordeste     PE   Belém do São Francisco     26  260160.0
# 295605  Nordeste     PE                   Recife     26  261160.0
# 287641  Nordeste     PE  Jaboatão dos Guararapes     26  260790.0
# 274067  Nordeste     PE                Araripina     26  260110.0
# 274429  Nordeste     PE       Barra de Guabiraba     26  260130.0
# 291804  Nordeste     PE                   Olinda     26  260960.0
# 293795  Nordeste     PE                 Paulista     26  261070.0
# 274610  Nordeste     PE                Barreiros     26  260140.0
# 412833  Nordeste     BA                   Wagner     29  293340.0
# 284927  Nordeste     PE                 Ibimirim     26  260660.0
# 412649  Nordeste     BA     Vitória da Conquista     29  293330.0
# ...
